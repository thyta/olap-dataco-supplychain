# %% [markdown]
# # import libraries and read csv

# %%
import pandas as pd
# writer = pd.ExcelWriter('dataframes.xlsx', engine='xlsxwriter')

# %%
DataCoSupplyChainDataset = pd.read_csv("DataCoSupplyChainDataset.csv", encoding='latin1')
DescriptionDataCoSupplyChain = pd.read_csv("DescriptionDataCoSupplyChain.csv")

# %%
DescriptionDataCoSupplyChain
# Out:
#                            FIELDS  \
# 0                            Type
# 1   Days for shipping (real)
# 2   Days for shipment (scheduled)
# 3               Benefit per order
# 4              Sales per customer
# 5                 Delivery Status
# 6   Late_delivery_risk
# 7                     Category Id
# 8                   Category Name
# 9                   Customer City
# 10               Customer Country
# 11                 Customer Email
# 12                 Customer Fname
# 13                    Customer Id
# 14                 Customer Lname
# 15              Customer Password
# 16               Customer Segment
# 17                 Customer State
# 18                Customer Street
# 19               Customer Zipcode
# 20                  Department Id
# 21                Department Name
# 22                       Latitude
# 23                      Longitude
# 24                         Market
# 25                     Order City
# 26                  Order Country
# ...

# %%
DataCoSupplyChainDataset['Department Name'].drop_duplicates()
# Out:
# 0                  Fitness
# 48                 Apparel
# 49                    Golf
# 55                Footwear
# 61                Outdoors
# 118               Fan Shop
# 145             Technology
# 1360             Book Shop
# 1585            Discs Shop
# 3205              Pet Shop
# 3208    Health and Beauty
# Name: Department Name, dtype: object

# %%
DataCoSupplyChainDataset[DataCoSupplyChainDataset['Department Name'] == 'Footwear'][['Category Id', 'Category Name']].drop_duplicates()
# Out:
#      Category Id        Category Name
# 55            13          Electronics
# 56            12         Boxing & MMA
# 59             9     Cardio Equipment
# 301           11  Fitness Accessories
# 316           16      As Seen on  TV!
# 547           10    Strength Training

# %%
DescriptionDataCoSupplyChain
# Out:
#                            FIELDS  \
# 0                            Type
# 1   Days for shipping (real)
# 2   Days for shipment (scheduled)
# 3               Benefit per order
# 4              Sales per customer
# 5                 Delivery Status
# 6   Late_delivery_risk
# 7                     Category Id
# 8                   Category Name
# 9                   Customer City
# 10               Customer Country
# 11                 Customer Email
# 12                 Customer Fname
# 13                    Customer Id
# 14                 Customer Lname
# 15              Customer Password
# 16               Customer Segment
# 17                 Customer State
# 18                Customer Street
# 19               Customer Zipcode
# 20                  Department Id
# 21                Department Name
# 22                       Latitude
# 23                      Longitude
# 24                         Market
# 25                     Order City
# 26                  Order Country
# ...

# %%
DataCoSupplyChainDataset.head(5)
# Out:
#        Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0     DEBIT                         3                              4
# 1  TRANSFER                         5                              4
# 2      CASH                         4                              4
# 3     DEBIT                         3                              4
# 4   PAYMENT                         2                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0          91.250000          314.640015  Advance shipping
# 1        -249.089996          311.359985     Late delivery
# 2        -247.779999          309.720001  Shipping on time
# 3          22.860001          304.809998  Advance shipping
# 4         134.210007          298.250000  Advance shipping
#
#    Late_delivery_risk  Category Id   Category Name Customer City  ...  \
# 0                   0           73  Sporting Goods        Caguas  ...
# ...

# %% [markdown]
# # Drop duplicate and n/a columns

# %%
print("origin height: " + str(DataCoSupplyChainDataset.shape) + " -- Drop duplicate: " + str(DataCoSupplyChainDataset.drop_duplicates().shape))
# Out:
# origin height: (180519, 53) -- Drop duplicate: (180519, 53)

# %%
DataCoSupplyChainDataset.isna().sum().sum()
# Out:
# 336209

# %%
DataCoSupplyChainDataset.drop(columns=['Product Description', 'Order Zipcode', 'Customer Zipcode'], axis=1, inplace=True)
DataCoSupplyChainDataset.dropna()
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
DataCoSupplyChainDataset.isna().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Email                   0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   8
# Customer Password                0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# Order Customer Id                0
# ...

# %% [markdown]
# # Generate ID for location, time, 'Order Status','Type', 'Shipping Mode','Delivery Status',

# %%
# Make a copy of the DataFrame
TempData = DataCoSupplyChainDataset.copy()

# Drop duplicates from TempData
TempData.drop_duplicates(inplace=True)

# Reset index after dropping duplicates in TempData
TempData.reset_index(drop=True, inplace=True)

# Add an ID for each unique combination of location columns in DataCoSupplyChainDataset
DataCoSupplyChainDataset['Location Id'] = TempData.groupby(['Market', 'Order City', 'Order Country', 'Order Region', 'Order State']).ngroup() + 1

# %%
DataCoSupplyChainDataset['shipping date (DateOrders)']
# Out:
# 0          2/3/2018 22:56
# 1         1/18/2018 12:27
# 2         1/17/2018 12:06
# 3         1/16/2018 11:45
# 4         1/15/2018 11:24
#                ...
# 180514     1/20/2016 3:40
# 180515     1/19/2016 1:34
# 180516    1/20/2016 21:00
# 180517    1/18/2016 20:18
# 180518    1/19/2016 18:54
# Name: shipping date (DateOrders), Length: 180519, dtype: object

# %%
# Make a copy of the DataFrame
TempData = DataCoSupplyChainDataset.copy()

# Drop duplicates from TempData
TempData['shipping date (DateOrders)'].drop_duplicates()

# Reset index after dropping duplicates in TempData
TempData.reset_index(drop=True, inplace=True)

# Add an ID for each unique combination of location columns in DataCoSupplyChainDataset
DataCoSupplyChainDataset['Time Id'] = TempData.groupby(['shipping date (DateOrders)']).ngroup() + 1

# %%
# Make a copy of the DataFrame
TempData = DataCoSupplyChainDataset.copy()

# Drop duplicates from TempData
TempData['Order Status'].drop_duplicates()

# Reset index after dropping duplicates in TempData
TempData.reset_index(drop=True, inplace=True)

# Add an ID for each unique combination of location columns in DataCoSupplyChainDataset
DataCoSupplyChainDataset['Order Status Id'] = TempData.groupby(['Order Status']).ngroup() + 1

# %%
# Make a copy of the DataFrame
TempData = DataCoSupplyChainDataset.copy()

# Drop duplicates from TempData
TempData['Type'].drop_duplicates()

# Reset index after dropping duplicates in TempData
TempData.reset_index(drop=True, inplace=True)

# Add an ID for each unique combination of location columns in DataCoSupplyChainDataset
DataCoSupplyChainDataset['Type Id'] = TempData.groupby(['Type']).ngroup() + 1

# %%
# Make a copy of the DataFrame
TempData = DataCoSupplyChainDataset.copy()

# Drop duplicates from TempData
TempData['Shipping Mode'].drop_duplicates()

# Reset index after dropping duplicates in TempData
TempData.reset_index(drop=True, inplace=True)

# Add an ID for each unique combination of location columns in DataCoSupplyChainDataset
DataCoSupplyChainDataset['Shipping Mode Id'] = TempData.groupby(['Shipping Mode']).ngroup() + 1

# %%
# Make a copy of the DataFrame
TempData = DataCoSupplyChainDataset.copy()

# Drop duplicates from TempData
TempData['Delivery Status'].drop_duplicates()

# Reset index after dropping duplicates in TempData
TempData.reset_index(drop=True, inplace=True)

# Add an ID for each unique combination of location columns in DataCoSupplyChainDataset
DataCoSupplyChainDataset['Delivery Status Id'] = TempData.groupby(['Delivery Status']).ngroup() + 1

# %% [markdown]
# # preprocess table SSIS

# %%
# List of customer-related columns
customer_columns = ['Customer Id', 'Customer Fname', 'Customer Lname']

# Create a new DataFrame containing only customer-related columns and drop duplicates
dim_customers = DataCoSupplyChainDataset[customer_columns].drop_duplicates()

# Reset index after dropping duplicates
dim_customers.reset_index(drop=True, inplace=True)

# Update the DataFrame (if needed)

# Sort dim_customers DataFrame based on 'Customer Id'
dim_customers_sorted = dim_customers.sort_values(by='Customer Id')

# Reset index after sorting
dim_customers_sorted.reset_index(drop=True, inplace=True)

# %%
# List of product-related columns
category_columns = ['Category Id',  'Category Name']

# Create a new DataFrame containing only product-related columns and drop duplicates
dim_categories = DataCoSupplyChainDataset[category_columns].drop_duplicates()

# Reset index after dropping duplicates
dim_categories.reset_index(drop=True, inplace=True)

# Sort dim_products DataFrame based on 'Product Card Id'
dim_categories_sorted = dim_categories.sort_values(by='Category Id')

# Reset index after sorting
dim_categories_sorted.reset_index(drop=True, inplace=True)

# %%
# List of product-related columns
product_columns = ['Product Card Id', 'Product Name', 'Product Price', 'Category Id']

# Create a new DataFrame containing only product-related columns and drop duplicates
dim_products = DataCoSupplyChainDataset[product_columns].drop_duplicates()

# Reset index after dropping duplicates
dim_products.reset_index(drop=True, inplace=True)

# Sort dim_products DataFrame based on 'Product Card Id'
dim_products_sorted = dim_products.sort_values(by='Product Card Id')

# Reset index after sorting
dim_products_sorted.reset_index(drop=True, inplace=True)

# %%
# List of location-related columns
location_columns = ['Location Id', 'Market', 'Order City', 'Order Country', 'Order Region', 'Order State']

# Create a new DataFrame containing only location-related columns and drop duplicates
dim_locations = DataCoSupplyChainDataset[location_columns].drop_duplicates()

# Reset index after dropping duplicates
dim_locations.reset_index(drop=True, inplace=True)

# Sort dim_locations DataFrame based on 'Location Id'
dim_locations_sorted = dim_locations.sort_values(by='Location Id')

# Reset index after sorting
dim_locations_sorted.reset_index(drop=True, inplace=True)

# %%
# List of time-related columns
time_columns = ['Time Id', 'shipping date (DateOrders)']

# Create a new DataFrame containing only time-related columns and drop duplicates
dim_times = DataCoSupplyChainDataset[time_columns].drop_duplicates()

# Reset index after dropping duplicates
dim_times.reset_index(drop=True, inplace=True)

# Sort dim_times DataFrame based on 'Time Id'
dim_times_sorted = dim_times.sort_values(by='Time Id')

# Reset index after sorting
dim_times_sorted.reset_index(drop=True, inplace=True)

dim_times_sorted['shipping date (DateOrders)'] = pd.to_datetime(dim_times_sorted['shipping date (DateOrders)'])

# Add a new column for the day of the week
dim_times_sorted['day of week'] = dim_times_sorted['shipping date (DateOrders)'].dt.day_name()

# %%
# List of time-related columns
order_status_columns = ['Order Status Id', 'Order Status']

# Create a new DataFrame containing only time-related columns and drop duplicates
order_statuses = DataCoSupplyChainDataset[order_status_columns].drop_duplicates()

# Reset index after dropping duplicates
order_statuses.reset_index(drop=True, inplace=True)

# Sort order_statuses DataFrame based on 'Order Status Id'
dim_order_statuses_sorted = order_statuses.sort_values(by='Order Status Id')

# Reset index after sorting
dim_order_statuses_sorted.reset_index(drop=True, inplace=True)

# %%
# List of time-related columns
type_columns = ['Type Id', 'Type']

# Create a new DataFrame containing only time-related columns and drop duplicates
types = DataCoSupplyChainDataset[type_columns].drop_duplicates()

# Reset index after dropping duplicates
types.reset_index(drop=True, inplace=True)

# Sort order_statuses DataFrame based on 'Type Id'
dim_types_sorted = types.sort_values(by='Type Id')

# Reset index after sorting
dim_types_sorted.reset_index(drop=True, inplace=True)

# %%
# List of time-related columns
shipping_mode_columns = ['Shipping Mode Id', 'Shipping Mode']

# Create a new DataFrame containing only time-related columns and drop duplicates
shipping_modes = DataCoSupplyChainDataset[shipping_mode_columns].drop_duplicates()

# Reset index after dropping duplicates
shipping_modes.reset_index(drop=True, inplace=True)

# Sort order_statuses DataFrame based on 'Type Id'
dim_shipping_modes_sorted = shipping_modes.sort_values(by='Shipping Mode Id')

# Reset index after sorting
dim_shipping_modes_sorted.reset_index(drop=True, inplace=True)

# %%
# List of time-related columns
delivery_status_columns = ['Delivery Status Id', 'Delivery Status']

# Create a new DataFrame containing only time-related columns and drop duplicates
delivery_statuses = DataCoSupplyChainDataset[delivery_status_columns].drop_duplicates()

# Reset index after dropping duplicates
delivery_statuses.reset_index(drop=True, inplace=True)

# Sort order_statuses DataFrame based on 'Delivery Status'
dim_delivery_statuses_sorted = delivery_statuses.sort_values(by='Delivery Status Id')

# Reset index after sorting
dim_delivery_statuses_sorted.reset_index(drop=True, inplace=True)

# %%
DataCoSupplyChainDataset.columns
# Out:
# Index(['Type', 'Days for shipping (real)', 'Days for shipment (scheduled)',
#        'Benefit per order', 'Sales per customer', 'Delivery Status',
#        'Late_delivery_risk', 'Category Id', 'Category Name', 'Customer City',
#        'Customer Country', 'Customer Email', 'Customer Fname', 'Customer Id',
#        'Customer Lname', 'Customer Password', 'Customer Segment',
#        'Customer State', 'Customer Street', 'Department Id', 'Department Name',
#        'Latitude', 'Longitude', 'Market', 'Order City', 'Order Country',
#        'Order Customer Id', 'order date (DateOrders)', 'Order Id',
#        'Order Item Cardprod Id', 'Order Item Discount',
#        'Order Item Discount Rate', 'Order Item Id', 'Order Item Product Price',
#        'Order Item Profit Ratio', 'Order Item Quantity', 'Sales',
#        'Order Item Total', 'Order Profit Per Order', 'Order Region',
#        'Order State', 'Order Status', 'Product Card Id', 'Product Category Id',
# ...

# %%
DataCoSupplyChainDataset[['Order Id','Order Item Id','Order Item Quantity','Product Price',
                          'Order Item Discount Rate',
                          'Order Profit Per Order','Benefit per order','Order Item Profit Ratio', 
                          'Sales per customer', 'Order Item Total', 'Sales'
                        ]].sort_values(by='Order Id').head(20)
# Out:
#         Order Id  Order Item Id  Order Item Quantity  Product Price  \
# 33833          1              1                    1     299.980011
# 77011          2              2                    1     199.990005
# 109322         2              3                    5      50.000000
# 87884          2              4                    1     129.990005
# 114915         4              8                    4      49.980000
# 95938          4              7                    3      50.000000
# 63764          4              5                    2      24.990000
# 96131          4              6                    5      59.990002
# 114914         5             11                    2      49.980000
# 58046          5             10                    5      59.990002
# 20680          5             12                    1     299.980011
# 20695          5              9                    1     299.980011
# 20305          5             13                    1     129.990005
# ...

# %%
fact_order_item_columns = ['Order Item Id',
                        
                            'Location Id', 'Time Id',
                            'Product Card Id', 'Customer Id',
                            'Order Status Id','Type Id', 'Shipping Mode Id','Delivery Status Id',
                           
                           'Days for shipping (real)', 'Days for shipment (scheduled)', 
                      
                           'Order Item Quantity', 'Order Item Discount Rate','Order Item Profit Ratio',
                           'Order Item Total', 'Benefit per order'
                           ]

fact_order_items = DataCoSupplyChainDataset[fact_order_item_columns]

# %%
# Check the number of rows in each DataFrame
print("Number of rows in dim_customers:", dim_customers_sorted.shape[0])
print("Number of rows in dim_locations:", dim_locations_sorted.shape[0])
print("Number of rows in dim_times:", dim_times_sorted.shape[0])
print("Number of rows in dim_types_sorted:", dim_types_sorted.shape[0])
print("Number of rows in dim_orders_status:", dim_order_statuses_sorted.shape[0])
print("Number of rows in dim_shipping_modes_sorted:", dim_shipping_modes_sorted.shape[0])
print("Number of rows in dim_categories_sorted:", dim_categories_sorted.shape[0])
print("Number of rows in dim_products_sorted:", dim_products_sorted.shape[0])
print("Number of rows in fact_order_item_columns:", fact_order_items.shape[0])
# Out:
# Number of rows in dim_customers: 20652
# Number of rows in dim_locations: 3772
# Number of rows in dim_times: 63701
# Number of rows in dim_types_sorted: 4
# Number of rows in dim_orders_status: 9
# Number of rows in dim_shipping_modes_sorted: 4
# Number of rows in dim_categories_sorted: 51
# Number of rows in dim_products_sorted: 118
# Number of rows in fact_order_item_columns: 180519

# %%
# Check for missing values in each DataFrame
print("Missing values in dim_customers:", dim_customers_sorted.isna().sum())
print("Missing values in dim_products:", dim_products_sorted.isna().sum())
print("Missing values in dim_locations:", dim_locations_sorted.isna().sum())
print("Missing values in dim_times:", dim_times_sorted.isna().sum())
print("Missing values in dim_types_sorted:", dim_types_sorted.isna().sum())
print("Missing values in dim_orders_status:", dim_order_statuses_sorted.isna().sum())
print("Missing values in dim_shipping_modes_sorted:", dim_shipping_modes_sorted.isna().sum())
print("Missing values in dim_categories_sorted:", dim_categories_sorted.isna().sum())
print("Missing values in fact_order_item_columns:", fact_order_items.isna().sum())
# Out:
# Missing values in dim_customers: Customer Id       0
# Customer Fname    0
# Customer Lname    8
# dtype: int64
# Missing values in dim_products: Product Card Id    0
# Product Name       0
# Product Price      0
# Category Id        0
# dtype: int64
# Missing values in dim_locations: Location Id      0
# Market           0
# Order City       0
# Order Country    0
# Order Region     0
# Order State      0
# dtype: int64
# Missing values in dim_times: Time Id                       0
# shipping date (DateOrders)    0
# day of week                   0
# dtype: int64
# Missing values in dim_types_sorted: Type Id    0
# Type       0
# dtype: int64
# Missing values in dim_orders_status: Order Status Id    0
# Order Status       0
# dtype: int64
# Missing values in dim_shipping_modes_sorted: Shipping Mode Id    0
# Shipping Mode       0
# dtype: int64
# Missing values in dim_categories_sorted: Category Id      0
# Category Name    0
# dtype: int64
# ...

# %%
# # Specify the full path along with the file name
# file_path = 'Preprocessed_DataCoSupplyChainDataset.xlsx'

# # Write each DataFrame to a separate worksheet
# with pd.ExcelWriter(file_path, engine='xlsxwriter') as writer:
#     dim_customers_sorted.to_excel(writer, sheet_name='dim_customers', index=False)
#     dim_products_sorted.to_excel(writer, sheet_name='dim_products', index=False)
#     dim_categories_sorted.to_excel(writer, sheet_name='dim_categories', index=False)
#     dim_locations_sorted.to_excel(writer, sheet_name='dim_locations', index=False)
#     dim_times_sorted.to_excel(writer, sheet_name='dim_times', index=False)
#     dim_order_statuses_sorted.to_excel(writer, sheet_name='dim_order_statuses', index=False)
#     dim_types_sorted.to_excel(writer, sheet_name='dim_types', index=False)
#     dim_shipping_modes_sorted.to_excel(writer, sheet_name='dim_shipping_modes', index=False)
#     dim_delivery_statuses_sorted.to_excel(writer, sheet_name=' dim_delivery_statuses', index=False)
#     fact_order_items.to_excel(writer, sheet_name='fact_order_items', index=False)

# print(f"DataFrames saved to '{file_path}' successfully.")

# %%
dim_locations_sorted
# Out:
#       Location Id  Market  Order City    Order Country  Order Region  \
# 0               1  Africa         Aba          Nigeria   West Africa
# 1               2  Africa   Abakaliki          Nigeria   West Africa
# 2               3  Africa    Abeokuta          Nigeria   West Africa
# 3               4  Africa     Abidjan  Costa de Marfil   West Africa
# 4               5  Africa   Abu Kabir           Egipto  North Africa
# ...           ...     ...         ...              ...           ...
# 3767         3768    USCA  Woonsocket   Estados Unidos   East of USA
# 3768         3769    USCA     Yonkers   Estados Unidos   East of USA
# 3769         3770    USCA        York   Estados Unidos   East of USA
# 3770         3771    USCA     Yucaipa   Estados Unidos  West of USA
# 3771         3772    USCA        Yuma   Estados Unidos  West of USA
#
#         Order State
# 0              Abia
# 1            Ebonyi
# 2              Ogun
# 3           Lagunes
# 4     Ash Sharqiyah
# ...
